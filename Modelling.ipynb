# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Rohlik Sales Forecasting Challenge
# Out:
# /content/drive/MyDrive/Colab Notebooks/Rohlik Sales Forecasting Challenge

# %% [markdown]
# ## Data Cleaning

# %%
train_df = pd.read_csv('data/sales_train.csv')
test_df = pd.read_csv('data/sales_test.csv')
inv_df = pd.read_csv('data/inventory.csv')
calendar = pd.read_csv('data/calendar.csv')

# %% [markdown]
# ### Date Formating

# %%
train_df['date'] = pd.to_datetime(train_df['date'])
test_df['date'] = pd.to_datetime(test_df['date'])
calendar['date'] = pd.to_datetime(calendar['date'])

# %% [markdown]
# ### Merging Tables

# %%
test_inv_merge = pd.merge(test_df, inv_df, on = ['unique_id','warehouse'],how = 'left')
test_inv_cal_merge = pd.merge(test_inv_merge, calendar, on = ['date','warehouse'],how = 'left').sort_values(by='date')

# %%
train_inv_merge = pd.merge(train_df, inv_df, on = ['unique_id','warehouse'],how = 'left')
train_inv_cal_merge = pd.merge(train_inv_merge, calendar, on = ['date','warehouse'],how = 'left').sort_values(by='date')

# %%
test_inv_cal_merge.isnull().sum()
# Out:
# unique_id                     0
# date                          0
# warehouse                     0
# total_orders                  0
# sell_price_main               0
# type_0_discount               0
# type_1_discount               0
# type_2_discount               0
# type_3_discount               0
# type_4_discount               0
# type_5_discount               0
# type_6_discount               0
# product_unique_id             0
# name                          0
# L1_category_name_en           0
# L2_category_name_en           0
# L3_category_name_en           0
# L4_category_name_en           0
# holiday_name              46544
# holiday                       0
# shops_closed                  0
# winter_school_holidays        0
# school_holidays               0
# dtype: int64

# %%
train_inv_cal_merge.isnull().sum()
# Out:
# unique_id                       0
# date                            0
# warehouse                       0
# total_orders                   52
# sales                          52
# sell_price_main                 0
# availability                    0
# type_0_discount                 0
# type_1_discount                 0
# type_2_discount                 0
# type_3_discount                 0
# type_4_discount                 0
# type_5_discount                 0
# type_6_discount                 0
# product_unique_id               0
# name                            0
# L1_category_name_en             0
# L2_category_name_en             0
# L3_category_name_en             0
# L4_category_name_en             0
# holiday_name              3844119
# holiday                         0
# shops_closed                    0
# winter_school_holidays          0
# school_holidays                 0
# dtype: int64

# %%
# Drop na
train_inv_cal_merge.dropna(inplace=True)

# %%
# Drop features
drop_columns=["unique_id", "product_unique_id", "L2_category_name_en", "L3_category_name_en", "L4_category_name_en", "holiday_name", "winter_school_holidays", "school_holidays"]

train_inv_cal_merge = train_inv_cal_merge.drop(columns=drop_columns)
train_inv_cal_merge = train_inv_cal_merge.drop(columns=['availability'])

test_inv_cal_merge = test_inv_cal_merge.drop(columns=drop_columns)

# %%
# Create feature
train_inv_cal_merge['weekday'] = train_inv_cal_merge['date'].dt.weekday
train_inv_cal_merge['month'] = train_inv_cal_merge['date'].dt.strftime('%m')
train_inv_cal_merge['day'] = train_inv_cal_merge['date'].dt.strftime('%d')
train_inv_cal_merge['name_cat'] = train_inv_cal_merge['name'].str.split('_').str[0]

test_inv_cal_merge['weekday'] = test_inv_cal_merge['date'].dt.weekday
test_inv_cal_merge['month'] = test_inv_cal_merge['date'].dt.strftime('%m')
test_inv_cal_merge['day'] = test_inv_cal_merge['date'].dt.strftime('%d')
test_inv_cal_merge['name_cat'] = test_inv_cal_merge['name'].str.split('_').str[0]

train_inv_cal_merge = train_inv_cal_merge.drop(columns=['date'])
test_inv_cal_merge = test_inv_cal_merge.drop(columns=['date'])

# %%
# Categorise and encode data
data_type = {'warehouse':'category', 'L1_category_name_en':'category', 'month':'category', 'day':'category', 'name_cat':'category', 'name':'category'}
train_inv_cal_merge = train_inv_cal_merge.astype(data_type)
test_inv_cal_merge = test_inv_cal_merge.astype(data_type)

cat_col = ['warehouse', 'L1_category_name_en','month', 'day', 'name_cat', 'name']
for col in cat_col:
    train_inv_cal_merge[col] = train_inv_cal_merge[col].cat.codes
    test_inv_cal_merge[col] = test_inv_cal_merge[col].cat.codes

# train_inv_cal_merge['warehouse'] = train_inv_cal_merge['warehouse'].cat.codes
# train_inv_cal_merge['L1_category_name_en'] = train_inv_cal_merge['L1_category_name_en'].cat.codes
# train_inv_cal_merge['month'] = train_inv_cal_merge['month'].cat.codes
# train_inv_cal_merge['day'] = train_inv_cal_merge['day'].cat.codes
# train_inv_cal_merge['name_cat'] = train_inv_cal_merge['name_cat'].cat.codes
# train_inv_cal_merge['name'] = train_inv_cal_merge['name'].cat.codes

# test_inv_cal_merge['warehouse'] = test_inv_cal_merge['warehouse'].cat.codes
# test_inv_cal_merge['L1_category_name_en'] = test_inv_cal_merge['L1_category_name_en'].cat.codes
# test_inv_cal_merge['month'] = test_inv_cal_merge['month'].cat.codes
# test_inv_cal_merge['day'] = test_inv_cal_merge['day'].cat.codes
# test_inv_cal_merge['name_cat'] = test_inv_cal_merge['name_cat'].cat.codes
# test_inv_cal_merge['name'] = test_inv_cal_merge['name'].cat.codes

# %%
train_inv_cal_merge = train_inv_cal_merge.drop(columns=['name_cat'])
test_inv_cal_merge = test_inv_cal_merge.drop(columns=['name_cat'])

# %% [markdown]
# ## Model

# %%
train_y = train_inv_cal_merge['sales']
train_X = train_inv_cal_merge.drop(columns='sales')
pred_X = test_inv_cal_merge

# %%
# Normalise
scaler = StandardScaler()

normalized_data_train_X = scaler.fit_transform(train_X)
train_X = pd.DataFrame(normalized_data_train_X, columns=train_X.columns)

normalized_data_pred_X = scaler.fit_transform(pred_X)
pred_X = pd.DataFrame(normalized_data_pred_X, columns=pred_X.columns)

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error
from xgboost import XGBRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X, train_y, test_size=0.2, random_state=10)

# %% [markdown]
# ### XGB Regressor

# %%
# param_grid = {
#     'n_estimators': [500],
#     'learning_rate': [0.2, 0.1],
#     'max_depth': [10],
#     'reg_alpha': [0],
#     'reg_lambda': [1],
#     'seed': [42],
#     'eval_metric': ['mae']
# }

# %%
# # Grid search
# xgb_reg = XGBRegressor(objective='reg:squarederror', random_state=42)

# clf = GridSearchCV(xgb_reg, param_grid, cv=5, n_jobs=-1, scoring='neg_mean_squared_error', verbose=3)
# clf.fit(X_train, y_train)

# print("Best parameters found: ", clf.best_params_)

# %%
# y_pred = clf.predict(X_test)
# rmse = mean_squared_error(y_test, y_pred)
# mae = mean_absolute_error(y_test, y_pred)

# print(f"RMSE: {rmse:.2f}")
# print(f"MAE: {mae:.2f}")

# %% [markdown]
# ### XGB

# %%
dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)
dtest = xgb.DMatrix(X_test, label=y_test, enable_categorical=True)

# %%
params = {
    'objective': 'reg:squarederror',
    'n_estimators': 500,
    'learning_rate': 0.1,
    'max_depth': 15,
    'seed': 42,
    'eval_metric': 'mae',
}

# %%
evals=[(dtrain, 'train') , (dtest, 'test')]
bst = xgb.train(params, dtrain, num_boost_round=500, early_stopping_rounds=20, evals=evals)
y_pred = bst.predict(dtest)


rmse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [15:41:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [0]	train-mae:95.85429	test-mae:94.80515
# [1]	train-mae:89.82656	test-mae:89.33536
# [2]	train-mae:84.34506	test-mae:84.37021
# [3]	train-mae:79.62053	test-mae:80.22320
# [4]	train-mae:75.34334	test-mae:76.42677
# [5]	train-mae:71.44020	test-mae:72.96500
# [6]	train-mae:67.83198	test-mae:69.94354
# [7]	train-mae:64.64036	test-mae:67.24265
# [8]	train-mae:61.63870	test-mae:64.72695
# [9]	train-mae:58.62024	test-mae:62.26784
# [10]	train-mae:56.09561	test-mae:60.22573
# [11]	train-mae:53.85182	test-mae:58.48897
# [12]	train-mae:51.75375	test-mae:56.87567
# [13]	train-mae:49.99540	test-mae:55.59706
# [14]	train-mae:48.17483	test-mae:54.28379
# [15]	train-mae:46.69104	test-mae:53.27393
# [16]	train-mae:45.26549	test-mae:52.33598
# [17]	train-mae:43.98924	test-mae:51.48471
# [18]	train-mae:42.49536	test-mae:50.43613
# [19]	train-mae:41.34617	test-mae:49.70774
# [20]	train-mae:39.90779	test-mae:48.72156
# [21]	train-mae:38.73828	test-mae:47.98502
# [22]	train-mae:38.05159	test-mae:47.64940
# [23]	train-mae:37.23701	test-mae:47.21226
# [24]	train-mae:36.32163	test-mae:46.66502
# [25]	train-mae:35.56629	test-mae:46.25205
# [26]	train-mae:34.67953	test-mae:45.70148
# [27]	train-mae:34.05800	test-mae:45.38896
# [28]	train-mae:33.56059	test-mae:45.16001
# [29]	train-mae:33.12014	test-mae:44.95626
# [30]	train-mae:32.50102	test-mae:44.57448
# [31]	train-mae:32.12962	test-mae:44.44943
# [32]	train-mae:31.57429	test-mae:44.12965
# [33]	train-mae:31.21005	test-mae:43.94605
# [34]	train-mae:30.90230	test-mae:43.83079
# [35]	train-mae:30.51776	test-mae:43.65414
# [36]	train-mae:30.27333	test-mae:43.58194
# [37]	train-mae:29.90226	test-mae:43.38432
# [38]	train-mae:29.52403	test-mae:43.17909
# [39]	train-mae:29.13598	test-mae:42.97081
# [40]	train-mae:28.87399	test-mae:42.87607
# [41]	train-mae:28.59041	test-mae:42.74140
# [42]	train-mae:28.10237	test-mae:42.48401
# [43]	train-mae:27.85203	test-mae:42.37114
# [44]	train-mae:27.54952	test-mae:42.25118
# [45]	train-mae:27.37375	test-mae:42.20391
# [46]	train-mae:27.20650	test-mae:42.15745
# [47]	train-mae:26.84801	test-mae:41.94360
# [48]	train-mae:26.51785	test-mae:41.74545
# [49]	train-mae:26.22115	test-mae:41.59540
# [50]	train-mae:25.94632	test-mae:41.44593
# [51]	train-mae:25.65966	test-mae:41.32196
# [52]	train-mae:25.30141	test-mae:41.11206
# [53]	train-mae:24.91065	test-mae:40.86693
# [54]	train-mae:24.61478	test-mae:40.71307
# [55]	train-mae:24.33541	test-mae:40.56324
# [56]	train-mae:24.15647	test-mae:40.48685
# [57]	train-mae:23.92636	test-mae:40.37851
# [58]	train-mae:23.72871	test-mae:40.34635
# [59]	train-mae:23.47780	test-mae:40.22561
# [60]	train-mae:23.26163	test-mae:40.13431
# [61]	train-mae:22.97966	test-mae:40.10288
# [62]	train-mae:22.84015	test-mae:40.08799
# [63]	train-mae:22.66863	test-mae:40.02921
# [64]	train-mae:22.47397	test-mae:39.98924
# [65]	train-mae:22.20800	test-mae:39.83782
# [66]	train-mae:22.01691	test-mae:39.81559
# [67]	train-mae:21.77901	test-mae:39.68261
# [68]	train-mae:21.67215	test-mae:39.64098
# [69]	train-mae:21.52574	test-mae:39.57418
# [70]	train-mae:21.38778	test-mae:39.54915
# [71]	train-mae:21.26760	test-mae:39.48870
# [72]	train-mae:21.19871	test-mae:39.45813
# [73]	train-mae:21.01303	test-mae:39.38339
# [74]	train-mae:20.82870	test-mae:39.34992
# [75]	train-mae:20.73946	test-mae:39.34196
# [76]	train-mae:20.58047	test-mae:39.33762
# [77]	train-mae:20.51139	test-mae:39.31383
# [78]	train-mae:20.41363	test-mae:39.28301
# [79]	train-mae:20.33886	test-mae:39.26677
# [80]	train-mae:20.21847	test-mae:39.21746
# [81]	train-mae:20.13789	test-mae:39.18463
# [82]	train-mae:20.05675	test-mae:39.14687
# [83]	train-mae:19.95736	test-mae:39.10929
# [84]	train-mae:19.82168	test-mae:39.03736
# [85]	train-mae:19.71286	test-mae:39.01054
# [86]	train-mae:19.62349	test-mae:38.97307
# [87]	train-mae:19.55020	test-mae:38.93963
# [88]	train-mae:19.30901	test-mae:38.82208
# [89]	train-mae:19.18193	test-mae:38.78022
# [90]	train-mae:19.11943	test-mae:38.74850
# [91]	train-mae:18.99471	test-mae:38.71561
# [92]	train-mae:18.88708	test-mae:38.67683
# [93]	train-mae:18.82219	test-mae:38.66512
# [94]	train-mae:18.60680	test-mae:38.54958
# [95]	train-mae:18.54488	test-mae:38.52726
# [96]	train-mae:18.43100	test-mae:38.47703
# [97]	train-mae:18.23619	test-mae:38.38387
# [98]	train-mae:18.06247	test-mae:38.29587
# [99]	train-mae:17.87285	test-mae:38.20688
# [100]	train-mae:17.73572	test-mae:38.19046
# [101]	train-mae:17.61547	test-mae:38.15037
# [102]	train-mae:17.50662	test-mae:38.13093
# [103]	train-mae:17.40116	test-mae:38.10897
# [104]	train-mae:17.27855	test-mae:38.05049
# [105]	train-mae:17.18149	test-mae:38.02366
# [106]	train-mae:17.10887	test-mae:38.00503
# [107]	train-mae:17.05850	test-mae:37.98688
# [108]	train-mae:16.94651	test-mae:37.94471
# [109]	train-mae:16.89479	test-mae:37.93414
# [110]	train-mae:16.86106	test-mae:37.93252
# [111]	train-mae:16.76945	test-mae:37.91364
# [112]	train-mae:16.72032	test-mae:37.89776
# [113]	train-mae:16.65975	test-mae:37.88771
# [114]	train-mae:16.51826	test-mae:37.84869
# [115]	train-mae:16.41961	test-mae:37.82157
# [116]	train-mae:16.37450	test-mae:37.81206
# [117]	train-mae:16.33502	test-mae:37.80411
# [118]	train-mae:16.28212	test-mae:37.79311
# [119]	train-mae:16.18686	test-mae:37.77797
# [120]	train-mae:16.10319	test-mae:37.75387
# [121]	train-mae:15.97351	test-mae:37.70238
# [122]	train-mae:15.84826	test-mae:37.66448
# [123]	train-mae:15.79336	test-mae:37.66151
# [124]	train-mae:15.72291	test-mae:37.65026
# [125]	train-mae:15.69759	test-mae:37.64778
# [126]	train-mae:15.58994	test-mae:37.63185
# [127]	train-mae:15.56148	test-mae:37.62957
# [128]	train-mae:15.50395	test-mae:37.59785
# [129]	train-mae:15.44189	test-mae:37.58341
# [130]	train-mae:15.41109	test-mae:37.57958
# [131]	train-mae:15.39062	test-mae:37.57759
# [132]	train-mae:15.35575	test-mae:37.56574
# [133]	train-mae:15.30314	test-mae:37.55696
# [134]	train-mae:15.15671	test-mae:37.49865
# [135]	train-mae:15.12059	test-mae:37.48644
# [136]	train-mae:15.10325	test-mae:37.48693
# [137]	train-mae:15.07142	test-mae:37.47741
# [138]	train-mae:15.04021	test-mae:37.47453
# [139]	train-mae:14.97045	test-mae:37.47225
# [140]	train-mae:14.86613	test-mae:37.43539
# [141]	train-mae:14.80457	test-mae:37.42381
# [142]	train-mae:14.78387	test-mae:37.42060
# [143]	train-mae:14.76829	test-mae:37.41879
# [144]	train-mae:14.69902	test-mae:37.39669
# [145]	train-mae:14.63373	test-mae:37.38358
# [146]	train-mae:14.54301	test-mae:37.36104
# [147]	train-mae:14.46386	test-mae:37.33599
# [148]	train-mae:14.35465	test-mae:37.30343
# [149]	train-mae:14.29164	test-mae:37.29725
# [150]	train-mae:14.20724	test-mae:37.27679
# [151]	train-mae:14.03815	test-mae:37.24343
# [152]	train-mae:13.98832	test-mae:37.23749
# [153]	train-mae:13.86009	test-mae:37.20559
# [154]	train-mae:13.78136	test-mae:37.20441
# [155]	train-mae:13.67032	test-mae:37.17554
# [156]	train-mae:13.54453	test-mae:37.15364
# [157]	train-mae:13.47426	test-mae:37.13986
# [158]	train-mae:13.39574	test-mae:37.11040
# [159]	train-mae:13.32916	test-mae:37.09622
# [160]	train-mae:13.27697	test-mae:37.08836
# [161]	train-mae:13.21229	test-mae:37.06956
# [162]	train-mae:13.12866	test-mae:37.04718
# [163]	train-mae:13.09308	test-mae:37.04409
# [164]	train-mae:12.97739	test-mae:37.02183
# [165]	train-mae:12.91017	test-mae:37.00396
# [166]	train-mae:12.85970	test-mae:36.99678
# [167]	train-mae:12.76423	test-mae:36.98297
# [168]	train-mae:12.73341	test-mae:36.97572
# [169]	train-mae:12.66817	test-mae:36.97285
# [170]	train-mae:12.62222	test-mae:36.96319
# [171]	train-mae:12.57689	test-mae:36.95421
# [172]	train-mae:12.49475	test-mae:36.94409
# [173]	train-mae:12.42850	test-mae:36.93505
# [174]	train-mae:12.35341	test-mae:36.93044
# [175]	train-mae:12.29123	test-mae:36.92209
# [176]	train-mae:12.19666	test-mae:36.89813
# [177]	train-mae:12.15001	test-mae:36.88404
# [178]	train-mae:12.07008	test-mae:36.87426
# [179]	train-mae:12.01920	test-mae:36.86052
# [180]	train-mae:11.98677	test-mae:36.85115
# [181]	train-mae:11.93659	test-mae:36.84905
# [182]	train-mae:11.88696	test-mae:36.84454
# [183]	train-mae:11.84740	test-mae:36.83859
# [184]	train-mae:11.83366	test-mae:36.83729
# [185]	train-mae:11.77242	test-mae:36.81804
# [186]	train-mae:11.74938	test-mae:36.81510
# [187]	train-mae:11.72559	test-mae:36.81556
# [188]	train-mae:11.70195	test-mae:36.81371
# [189]	train-mae:11.67675	test-mae:36.81165
# [190]	train-mae:11.58906	test-mae:36.81227
# [191]	train-mae:11.51635	test-mae:36.80348
# [192]	train-mae:11.44692	test-mae:36.78783
# [193]	train-mae:11.37833	test-mae:36.77715
# [194]	train-mae:11.34132	test-mae:36.77406
# [195]	train-mae:11.24746	test-mae:36.75558
# [196]	train-mae:11.21370	test-mae:36.75543
# [197]	train-mae:11.13775	test-mae:36.75569
# [198]	train-mae:11.08762	test-mae:36.74243
# [199]	train-mae:11.04789	test-mae:36.73746
# [200]	train-mae:10.99644	test-mae:36.73848
# [201]	train-mae:10.93003	test-mae:36.71836
# [202]	train-mae:10.86925	test-mae:36.70977
# [203]	train-mae:10.85403	test-mae:36.70695
# [204]	train-mae:10.83030	test-mae:36.70531
# [205]	train-mae:10.79344	test-mae:36.69769
# [206]	train-mae:10.75372	test-mae:36.69493
# [207]	train-mae:10.71334	test-mae:36.68650
# [208]	train-mae:10.63839	test-mae:36.69152
# [209]	train-mae:10.57280	test-mae:36.69558
# [210]	train-mae:10.52113	test-mae:36.69846
# [211]	train-mae:10.46467	test-mae:36.70395
# [212]	train-mae:10.41202	test-mae:36.70019
# [213]	train-mae:10.35894	test-mae:36.69811
# [214]	train-mae:10.33247	test-mae:36.69827
# [215]	train-mae:10.28673	test-mae:36.69411
# [216]	train-mae:10.22675	test-mae:36.68802
# [217]	train-mae:10.19894	test-mae:36.69003
# [218]	train-mae:10.15797	test-mae:36.67808
# [219]	train-mae:10.09004	test-mae:36.66336
# [220]	train-mae:10.02623	test-mae:36.66285
# [221]	train-mae:10.01283	test-mae:36.66280
# [222]	train-mae:9.94349	test-mae:36.64410
# [223]	train-mae:9.91684	test-mae:36.64440
# [224]	train-mae:9.90257	test-mae:36.64392
# [225]	train-mae:9.87947	test-mae:36.63954
# [226]	train-mae:9.87016	test-mae:36.63952
# [227]	train-mae:9.84680	test-mae:36.63696
# [228]	train-mae:9.82069	test-mae:36.63328
# [229]	train-mae:9.80610	test-mae:36.63145
# [230]	train-mae:9.79429	test-mae:36.63203
# [231]	train-mae:9.78864	test-mae:36.63111
# [232]	train-mae:9.76773	test-mae:36.63318
# [233]	train-mae:9.75365	test-mae:36.63175
# [234]	train-mae:9.71474	test-mae:36.63055
# [235]	train-mae:9.66239	test-mae:36.62138
# [236]	train-mae:9.61757	test-mae:36.61262
# [237]	train-mae:9.59157	test-mae:36.60827
# [238]	train-mae:9.55551	test-mae:36.60415
# [239]	train-mae:9.52366	test-mae:36.60152
# [240]	train-mae:9.47194	test-mae:36.59689
# [241]	train-mae:9.43204	test-mae:36.59319
# [242]	train-mae:9.35143	test-mae:36.58601
# [243]	train-mae:9.29101	test-mae:36.57640
# [244]	train-mae:9.24510	test-mae:36.57378
# [245]	train-mae:9.21550	test-mae:36.57570
# [246]	train-mae:9.17195	test-mae:36.57477
# [247]	train-mae:9.13964	test-mae:36.57497
# [248]	train-mae:9.06758	test-mae:36.57228
# [249]	train-mae:9.04327	test-mae:36.56980
# [250]	train-mae:9.00830	test-mae:36.56746
# [251]	train-mae:8.94119	test-mae:36.56033
# [252]	train-mae:8.90338	test-mae:36.55965
# [253]	train-mae:8.87798	test-mae:36.56003
# [254]	train-mae:8.86109	test-mae:36.56074
# [255]	train-mae:8.81598	test-mae:36.55822
# [256]	train-mae:8.80252	test-mae:36.55989
# [257]	train-mae:8.73828	test-mae:36.54620
# [258]	train-mae:8.72991	test-mae:36.54685
# [259]	train-mae:8.69700	test-mae:36.54794
# [260]	train-mae:8.66412	test-mae:36.54739
# [261]	train-mae:8.65098	test-mae:36.54973
# [262]	train-mae:8.64622	test-mae:36.54889
# [263]	train-mae:8.61607	test-mae:36.54190
# [264]	train-mae:8.54574	test-mae:36.53173
# [265]	train-mae:8.53983	test-mae:36.53108
# [266]	train-mae:8.51875	test-mae:36.53000
# [267]	train-mae:8.50622	test-mae:36.52885
# [268]	train-mae:8.50250	test-mae:36.52887
# [269]	train-mae:8.48433	test-mae:36.52865
# [270]	train-mae:8.47558	test-mae:36.52876
# [271]	train-mae:8.46764	test-mae:36.52899
# [272]	train-mae:8.45607	test-mae:36.52755
# [273]	train-mae:8.43271	test-mae:36.52723
# [274]	train-mae:8.39659	test-mae:36.52662
# [275]	train-mae:8.39399	test-mae:36.52654
# [276]	train-mae:8.39112	test-mae:36.52662
# [277]	train-mae:8.38730	test-mae:36.52668
# [278]	train-mae:8.38229	test-mae:36.52648
# [279]	train-mae:8.37921	test-mae:36.52621
# [280]	train-mae:8.35884	test-mae:36.52570
# [281]	train-mae:8.33622	test-mae:36.52463
# [282]	train-mae:8.32293	test-mae:36.52647
# [283]	train-mae:8.31444	test-mae:36.52608
# [284]	train-mae:8.30271	test-mae:36.52427
# [285]	train-mae:8.26718	test-mae:36.52305
# [286]	train-mae:8.25962	test-mae:36.52385
# [287]	train-mae:8.23773	test-mae:36.52065
# [288]	train-mae:8.23172	test-mae:36.51811
# [289]	train-mae:8.17288	test-mae:36.51614
# [290]	train-mae:8.15798	test-mae:36.51512
# [291]	train-mae:8.12721	test-mae:36.51717
# [292]	train-mae:8.06769	test-mae:36.51237
# [293]	train-mae:8.03767	test-mae:36.51283
# [294]	train-mae:8.00316	test-mae:36.51186
# [295]	train-mae:7.97726	test-mae:36.51311
# [296]	train-mae:7.96455	test-mae:36.51152
# [297]	train-mae:7.94182	test-mae:36.51138
# [298]	train-mae:7.88131	test-mae:36.50931
# [299]	train-mae:7.83151	test-mae:36.50705
# [300]	train-mae:7.81982	test-mae:36.50799
# [301]	train-mae:7.80163	test-mae:36.50589
# [302]	train-mae:7.76158	test-mae:36.50136
# [303]	train-mae:7.71941	test-mae:36.49763
# [304]	train-mae:7.69236	test-mae:36.49354
# [305]	train-mae:7.65100	test-mae:36.48807
# [306]	train-mae:7.62797	test-mae:36.48707
# [307]	train-mae:7.59716	test-mae:36.48629
# [308]	train-mae:7.57357	test-mae:36.48462
# [309]	train-mae:7.56314	test-mae:36.48397
# [310]	train-mae:7.54206	test-mae:36.48293
# [311]	train-mae:7.53351	test-mae:36.48262
# [312]	train-mae:7.49798	test-mae:36.48306
# [313]	train-mae:7.47790	test-mae:36.48117
# [314]	train-mae:7.45027	test-mae:36.48132
# [315]	train-mae:7.43771	test-mae:36.48050
# [316]	train-mae:7.41192	test-mae:36.47927
# [317]	train-mae:7.38397	test-mae:36.48214
# [318]	train-mae:7.37794	test-mae:36.48334
# [319]	train-mae:7.36139	test-mae:36.48426
# [320]	train-mae:7.34213	test-mae:36.48087
# [321]	train-mae:7.29411	test-mae:36.48292
# [322]	train-mae:7.28109	test-mae:36.48176
# [323]	train-mae:7.24745	test-mae:36.47758
# [324]	train-mae:7.21357	test-mae:36.46983
# [325]	train-mae:7.17323	test-mae:36.47113
# [326]	train-mae:7.15001	test-mae:36.47473
# [327]	train-mae:7.11120	test-mae:36.46990
# [328]	train-mae:7.06985	test-mae:36.46542
# [329]	train-mae:7.06298	test-mae:36.46403
# [330]	train-mae:7.04541	test-mae:36.46404
# [331]	train-mae:7.02112	test-mae:36.46100
# [332]	train-mae:6.98330	test-mae:36.45877
# [333]	train-mae:6.97228	test-mae:36.45742
# [334]	train-mae:6.96870	test-mae:36.45812
# [335]	train-mae:6.95788	test-mae:36.45816
# [336]	train-mae:6.95236	test-mae:36.45754
# [337]	train-mae:6.94341	test-mae:36.45673
# [338]	train-mae:6.93766	test-mae:36.45530
# [339]	train-mae:6.92545	test-mae:36.45599
# [340]	train-mae:6.92068	test-mae:36.45650
# [341]	train-mae:6.91142	test-mae:36.45654
# [342]	train-mae:6.90298	test-mae:36.45685
# [343]	train-mae:6.89858	test-mae:36.45645
# [344]	train-mae:6.86193	test-mae:36.45629
# [345]	train-mae:6.85900	test-mae:36.45637
# [346]	train-mae:6.82566	test-mae:36.45787
# [347]	train-mae:6.80450	test-mae:36.45946
# [348]	train-mae:6.78245	test-mae:36.45644
# [349]	train-mae:6.75709	test-mae:36.45464
# [350]	train-mae:6.73706	test-mae:36.45372
# [351]	train-mae:6.70172	test-mae:36.44800
# [352]	train-mae:6.68882	test-mae:36.44674
# [353]	train-mae:6.68246	test-mae:36.44667
# [354]	train-mae:6.66764	test-mae:36.44774
# [355]	train-mae:6.64385	test-mae:36.44789
# [356]	train-mae:6.63075	test-mae:36.44736
# [357]	train-mae:6.61889	test-mae:36.44801
# [358]	train-mae:6.58235	test-mae:36.44485
# [359]	train-mae:6.56607	test-mae:36.44577
# [360]	train-mae:6.53634	test-mae:36.44240
# [361]	train-mae:6.50133	test-mae:36.43601
# [362]	train-mae:6.48050	test-mae:36.43591
# [363]	train-mae:6.44844	test-mae:36.44020
# [364]	train-mae:6.42433	test-mae:36.44038
# [365]	train-mae:6.39064	test-mae:36.43676
# [366]	train-mae:6.35194	test-mae:36.43806
# [367]	train-mae:6.32159	test-mae:36.43650
# [368]	train-mae:6.29409	test-mae:36.43852
# [369]	train-mae:6.26785	test-mae:36.43624
# [370]	train-mae:6.24320	test-mae:36.43701
# [371]	train-mae:6.24107	test-mae:36.43711
# [372]	train-mae:6.23409	test-mae:36.43589
# [373]	train-mae:6.23109	test-mae:36.43639
# [374]	train-mae:6.21139	test-mae:36.43649
# [375]	train-mae:6.20549	test-mae:36.43636
# [376]	train-mae:6.18921	test-mae:36.43398
# [377]	train-mae:6.17127	test-mae:36.43569
# [378]	train-mae:6.16885	test-mae:36.43587
# [379]	train-mae:6.16196	test-mae:36.43517
# [380]	train-mae:6.14847	test-mae:36.43514
# [381]	train-mae:6.14690	test-mae:36.43542
# [382]	train-mae:6.13691	test-mae:36.43465
# [383]	train-mae:6.10624	test-mae:36.43297
# [384]	train-mae:6.08401	test-mae:36.43209
# [385]	train-mae:6.06766	test-mae:36.43230
# [386]	train-mae:6.03983	test-mae:36.43393
# [387]	train-mae:6.01326	test-mae:36.43310
# [388]	train-mae:5.98819	test-mae:36.43029
# [389]	train-mae:5.96263	test-mae:36.42886
# [390]	train-mae:5.95343	test-mae:36.42956
# [391]	train-mae:5.94709	test-mae:36.42998
# [392]	train-mae:5.93703	test-mae:36.43150
# [393]	train-mae:5.92707	test-mae:36.43016
# [394]	train-mae:5.92318	test-mae:36.43045
# [395]	train-mae:5.90394	test-mae:36.43108
# [396]	train-mae:5.89724	test-mae:36.43141
# [397]	train-mae:5.89348	test-mae:36.43197
# [398]	train-mae:5.86214	test-mae:36.42919
# [399]	train-mae:5.83824	test-mae:36.43019
# [400]	train-mae:5.81984	test-mae:36.43141
# [401]	train-mae:5.81575	test-mae:36.43012
# [402]	train-mae:5.80603	test-mae:36.43101
# [403]	train-mae:5.79745	test-mae:36.43251
# [404]	train-mae:5.78115	test-mae:36.43290
# [405]	train-mae:5.76220	test-mae:36.43396
# [406]	train-mae:5.73892	test-mae:36.43201
# [407]	train-mae:5.72319	test-mae:36.42988
# [408]	train-mae:5.71007	test-mae:36.43093
# RMSE: 12952.43
# MAE: 36.43

# %%
feature_gain = bst.get_score(importance_type='weight')
sorted(feature_gain.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('total_orders', 315037.0),
#  ('sell_price_main', 308893.0),
#  ('name', 252309.0),
#  ('warehouse', 84865.0),
#  ('weekday', 81127.0),
#  ('day', 63359.0),
#  ('month', 61034.0),
#  ('type_6_discount', 32406.0),
#  ('type_0_discount', 28619.0),
#  ('shops_closed', 19796.0),
#  ('L1_category_name_en', 15083.0),
#  ('type_4_discount', 10895.0),
#  ('holiday', 9145.0),
#  ('type_2_discount', 4162.0),
#  ('type_5_discount', 2296.0),
#  ('type_1_discount', 482.0),
#  ('type_3_discount', 68.0)]
